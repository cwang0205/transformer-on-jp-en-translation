# %%
# !pip install transformers

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math

import json
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Configuration object to store hyperparameters
class Config:
    def __init__(self):
        self.vocab_size = 119547            # e.g., BERT-base vocab size
        self.hidden_size = 768              # model embedding size
        self.max_position_embeddings = 512  # maximum sequence length
        self.hidden_dropout_prob = 0.1    # 10% probability of dropping (zeroing out) each element in the input tensor during training
        self.intermediate_size = 3072       # FFN inner layer size (usually 4*hidden_size)
        self.num_attention_heads = 12
        self.num_encoder_layers = 6         # number of encoder layers
        self.num_decoder_layers = 6         # number of decoder layers

config = Config()

# %%
# Embeddings module: token embeddings + positional embeddings
class Embeddings(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.token_embeddings = nn.Embedding(config.vocab_size, config.hidden_size) # output of this embedding lookup is a tensor of shape (batch_size, sequence_length, hidden_size)
        self.position_embeddings = nn.Embedding(config.max_position_embeddings,
                                                config.hidden_size)
        self.layer_norm = nn.LayerNorm(config.hidden_size, eps=1e-12)
        self.dropout = nn.Dropout(config.hidden_dropout_prob) # define dropout rate from config param

    def forward(self, input_ids):
        # input_ids shape: (batch_size, seq_length)
        seq_length = input_ids.size(1)
        # Create position IDs: (1, seq_length)
        position_ids = torch.arange(seq_length, dtype=torch.long, device=input_ids.device).unsqueeze(0)
        # Look up token and position embeddings
        token_embeddings = self.token_embeddings(input_ids)           # (batch_size, seq_length, hidden_size)
        position_embeddings = self.position_embeddings(position_ids)    # (1, seq_length, hidden_size)
        embeddings = token_embeddings + position_embeddings  # Broadcasting over batch dimension
        embeddings = self.layer_norm(embeddings)
        embeddings = self.dropout(embeddings)
        # print("Embeddings output shape:", embeddings.shape) #print
        return embeddings

# attention function
def scaled_dot_product_attention(query, key, value, mask=None):
    dim_k = query.size(-1)
    scores = torch.bmm(query, key.transpose(1, 2)) / math.sqrt(dim_k)
    if mask is not None:
        scores = scores.masked_fill(mask == 0, float("-inf"))
    weights = F.softmax(scores, dim=-1)
    return torch.bmm(weights, value)

class AttentionHead(nn.Module):
    def __init__(self, embed_dim, head_dim): # embed_dim is define in hidden_size
        super().__init__()
        self.q = nn.Linear(embed_dim, head_dim)
        self.k = nn.Linear(embed_dim, head_dim)
        self.v = nn.Linear(embed_dim, head_dim)

    def forward(self, query, key, value):
        return scaled_dot_product_attention(
            self.q(query), self.k(key), self.v(value)
        )

class MultiHeadAttention(nn.Module):
    def __init__(self, config):
        super().__init__()
        embed_dim = config.hidden_size
        num_heads = config.num_attention_heads
        head_dim = embed_dim // num_heads
        self.heads = nn.ModuleList(
            [AttentionHead(embed_dim, head_dim) for _ in range(num_heads)]
        )
        self.output_linear = nn.Linear(embed_dim, embed_dim)

    def forward(self, query, key=None, value=None, mask=None):
        # If key or value is not provided, default to query (i.e., self-attention)
        if key is None:
            key = query
        if value is None:
            value = query
        # Each head returns a tensor of shape: (batch_size, seq_length, head_dim)
        head_outputs = [h(query, key, value) for h in self.heads]
        # Concatenate on the last dimension: shape becomes (batch_size, seq_length, embed_dim)
        x = torch.cat(head_outputs, dim=-1)
        # print("Concatenated heads shape:", x.shape) #！！
        x = self.output_linear(x)
        # print("MultiHeadAttention output shape:", x.shape)#！！
        return x

class FeedForward(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.linear_1 = nn.Linear(config.hidden_size, config.intermediate_size) #Expanding the dimensionality provides the model with more capacity to capture complex patterns and relationships within each token's representation
        self.gelu = nn.GELU() #GELU is smoother than ReLU. This smooth behavior can lead to better gradient flow
        self.linear_2 = nn.Linear(config.intermediate_size, config.hidden_size)
        self.dropout = nn.Dropout(config.hidden_dropout_prob)

    def forward(self, x):
        x = self.linear_1(x)
        x = self.gelu(x)
        x = self.linear_2(x)
        x = self.dropout(x)
        return x

# %%
# Transformer Encoder Layer: attention + feed-forward, with residual connections
class TransformerEncoderLayer(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.layer_norm_1 = nn.LayerNorm(config.hidden_size)
        self.layer_norm_2 = nn.LayerNorm(config.hidden_size)
        self.attention = MultiHeadAttention(config)
        self.feed_forward = FeedForward(config)

    def forward(self, x):
        # Pre-layer normalization before attention
        hidden_state = self.layer_norm_1(x)
        # Residual Connection:The attention output is added back to the original x,preserve the original information while integrating new
        x = x + self.attention(hidden_state)
        # Pre-layer normalization before feed-forward, then
        # residual connection
        x = x + self.feed_forward(self.layer_norm_2(x))
        return x

# Transformer Encoder: stacking multiple encoder layers
class TransformerEncoder(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.embeddings = Embeddings(config)
        self.layers = nn.ModuleList([TransformerEncoderLayer(config)
                                     for _ in range(config.num_encoder_layers)]) # encoder_layers, defined in config
    def forward(self, input_ids):
        x = self.embeddings(input_ids)
        for layer in self.layers:
            x = layer(x)
        return x  # shape: (batch_size, seq_length, hidden_size)

# %%
# Transformer Decoder Layer: has two attention sub-layers
class TransformerDecoderLayer(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.layer_norm_1 = nn.LayerNorm(config.hidden_size)
        self.layer_norm_2 = nn.LayerNorm(config.hidden_size)
        self.layer_norm_3 = nn.LayerNorm(config.hidden_size)
        # Masked self-attention for decoder (prevent future tokens)
        self.masked_attention = MultiHeadAttention(config)
        # Encoder-decoder (cross) attention: here we assume same MultiHeadAttention;
        # In practice, keys and values come from encoder outputs.
        self.enc_dec_attention = MultiHeadAttention(config)
        self.feed_forward = FeedForward(config)

    def forward(self, x, memory, tgt_mask=None):
        # Masked self-attention sub-layer
        hidden_state = self.layer_norm_1(x)
         # residual connection
        x = x + self.masked_attention(hidden_state, mask=tgt_mask)
        # Encoder-decoder (cross) attention: query from decoder; key & value from encoder memory
        hidden_state2 = self.layer_norm_2(x)
         # residual connection
        #  pass memory here
        x = x + self.enc_dec_attention(hidden_state2, key=memory, value=memory)
        # Feed-forward sub-layer & residual connection
        x = x + self.feed_forward(self.layer_norm_3(x))
        return x

# Transformer Decoder: stacking multiple decoder layers
class TransformerDecoder(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.embeddings = Embeddings(config)  # for target tokens
        self.layers = nn.ModuleList([TransformerDecoderLayer(config)
                                     for _ in range(config.num_decoder_layers)])
    def forward(self, target_ids, memory, tgt_mask=None):
        x = self.embeddings(target_ids)
        for layer in self.layers:
            x = layer(x, memory, tgt_mask=tgt_mask)
        return x  # shape: (batch_size, target_seq_length, hidden_size)

# %%
# mask
def generate_tgt_mask(seq_length, device=None):
    """
    Generates a target mask for a sequence of given length.

    The mask is a lower triangular matrix of shape (1, seq_length, seq_length),
    where positions with 1 indicate allowed attention and 0 indicate masked positions.

    Args:
        seq_length (int): The length of the target sequence.
        device (torch.device or None): The device on which to create the mask.

    Returns:
        torch.Tensor: A mask tensor of shape (1, seq_length, seq_length).
    """
    # Create a lower triangular matrix filled with 1s (allowed positions)
    mask = torch.tril(torch.ones(seq_length, seq_length, device=device))
    # Unsqueeze to add a batch dimension for broadcasting: (1, seq_length, seq_length)
    mask = mask.unsqueeze(0)
    return mask

# %%
# Full Transformer Model: connects encoder and decoder
class TransformerModel(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.encoder = TransformerEncoder(config)
        self.decoder = TransformerDecoder(config)
        self.output_linear = nn.Linear(config.hidden_size, config.vocab_size)

    def forward(self, src_ids, tgt_ids, tgt_mask=None):
        memory = self.encoder(src_ids)
        decoder_output = self.decoder(tgt_ids, memory, tgt_mask=tgt_mask)
        logits = self.output_linear(decoder_output)
        return logits  # shape: (batch_size, tgt_seq_length, vocab_size)

# %% [markdown]
# # data prep

# %%
with open("/content/drive/MyDrive/transformer/train.json","r",encoding="utf-8") as f:
    data=json.load(f)
# print("Number of examples:", len(data))
# print(json.dumps(data[0], indent=2))

df = pd.DataFrame(data)
df.shape

df_exploded = df.explode("conversation")
# Reset index for convenience
df_exploded = df_exploded.reset_index(drop=True)
# Normalize the "conversation" column into separate columns
conversation_df = pd.json_normalize(df_exploded["conversation"])
# Merge the normalized data back into the exploded df
df_exploded = df_exploded.drop("conversation", axis=1).join(conversation_df)
# only need the ja_sentance and en_sentence columns
train_data=df_exploded[["ja_sentence","en_sentence"]]

train_data=train_data[:20000]

# %% [markdown]
# data prep for model

# %%
# clean - removing unwanted characters, normalizing punctuation, etc

# tokenizing
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-multilingual-cased") # this impact token size

# Tokenize sentences with special tokens (like [CLS], [SEP] or <sos>, <eos> depending on the model)
train_data["src_ids"] = train_data["ja_sentence"].apply(lambda s: tokenizer.encode(s, add_special_tokens=True))
train_data["tgt_ids"] = train_data["en_sentence"].apply(lambda s: tokenizer.encode(s, add_special_tokens=True))

# padding them to a fixed length
from torch.nn.utils.rnn import pad_sequence
# creates two Python lists—one for the source sentences and one for the target sentences.
# Each element in these lists is a PyTorch tensor that contains the token IDs for one sentence.
src_id_tensors = [torch.tensor(ids) for ids in train_data["src_ids"]]
tgt_id_tensors = [torch.tensor(ids) for ids in train_data["tgt_ids"]]
# Use the tokenizer's pad token ID for padding
src_padded = pad_sequence(src_id_tensors, batch_first=True, padding_value=tokenizer.pad_token_id)
tgt_padded = pad_sequence(tgt_id_tensors, batch_first=True, padding_value=tokenizer.pad_token_id)

# batch
from torch.utils.data import TensorDataset, DataLoader
dataset = TensorDataset(src_padded, tgt_padded)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
max_src = max([max(ids) for ids in train_data["src_ids"] if ids])
max_tgt = max([max(ids) for ids in train_data["tgt_ids"] if ids])
print("Max source token ID:", max_src)
print("Max target token ID:", max_tgt)
print("Tokenizer vocab size:", tokenizer.vocab_size)
# Out:
# Max source token ID: 119539
# Max target token ID: 110790
# Tokenizer vocab size: 119547

# %% [markdown]
# # training

# %%
import torch.optim as optim

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Instantiate the model with your configuration and move it to the device.
model = TransformerModel(config).to(device)

# Define the loss function.
# CrossEntropyLoss is used for classification tasks, and we ignore the pad token.
criterion = nn.CrossEntropyLoss(ignore_index=tokenizer.pad_token_id)

# Define an optimizer, here we use Adam.
optimizer = optim.Adam(model.parameters(), lr=1e-4)

model.train()
num_epochs = 5
epoch_result=[]
# Iterate over epochs.
for epoch in range(num_epochs):
    epoch_loss = 0.0

    # Iterate over batches from the DataLoader.
    for batch in dataloader:
        #   src_ids: Padded token IDs for source sentences (shape: [batch_size, src_seq_len])
        #   tgt_ids: Padded token IDs for target sentences (shape: [batch_size, tgt_seq_len])
        src_ids, tgt_ids = batch
        src_ids = src_ids.to(device)
        # print("src:", src_ids.shape)
        tgt_ids = tgt_ids.to(device)
        # print("tgt:", tgt_ids.shape)

        # shift the target sequence: ensures that at every time step the model’s input is the sequence of previous tokens, and it’s trained to predict the next token.
        #   - decoder_input: All tokens except the last one.
        #   - target_output: All tokens except the first one.
        decoder_input = tgt_ids[:, :-1]   # shape: (batch_size, tgt_seq_len - 1),shifting it removes one token from each end:
        target_output = tgt_ids[:, 1:]      # shape: (batch_size, tgt_seq_len - 1)
        print("decoder_input:", decoder_input.shape)
        print("target_output:", target_output.shape)

        # Generate a target mask to enforce causality in the decoder.
        # This mask prevents each token from attending to future tokens.
        seq_length = decoder_input.size(1)
        tgt_mask = generate_tgt_mask(seq_length, device=decoder_input.device)

        # Forward pass: pass source and decoder inputs through the model.
        # The model expects (src_ids, decoder_input, tgt_mask).
        logits = model(src_ids, decoder_input, tgt_mask=tgt_mask)
        # logits shape: (batch_size, tgt_seq_len - 1, vocab_size)
        print("Logits shape:", logits.shape)

        # Reshape logits and target_output for loss computation.
        # We flatten the batch and sequence dimensions.
        logits = logits.reshape(-1, config.vocab_size)
        target_output = target_output.reshape(-1)

        # Compute the loss.
        loss = criterion(logits, target_output)
        print("Loss:", loss.item())
        # Backpropagation and parameter update.
        optimizer.zero_grad()   # Clear previous gradients
        loss.backward()         # Compute new gradients
        optimizer.step()        # Update the model's parameters

        epoch_loss += loss.item()

    average_loss = epoch_loss / len(dataloader)
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {average_loss:.4f}")
    epoch_result.append([epoch,average_loss])
# Out:
# Streaming output truncated to the last 5000 lines.
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00391631294041872
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.009684890508651733
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.017776858061552048
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.010464549995958805
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007731452118605375
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.011778922751545906
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.021474473178386688
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007671731058508158
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.021728461608290672
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.009533751755952835
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.009533219039440155
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.009110799990594387
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.02108474262058735
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.013064752332866192
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.009716209024190903
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007149263750761747
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0077234599739313126
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.011466365307569504
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0211427491158247
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.026725467294454575
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007372157648205757
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006478157360106707
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.024830598384141922
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.005585505627095699
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.010925392620265484
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.022889146581292152
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007980721071362495
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007729750592261553
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.010534139350056648
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00688359048217535
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006409704685211182
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.011267036199569702
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.025449618697166443
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.01420101709663868
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.01221045758575201
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.009632356464862823
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.011169102974236012
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.008958399295806885
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.017730917781591415
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0050159781239926815
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.011817573569715023
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.005702510476112366
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.005897125694900751
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.005715703591704369
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004947504494339228
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.031623415648937225
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.010307875461876392
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004121108911931515
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.002668403321877122
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.014395063742995262
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.008936461061239243
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.008892369456589222
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.01627400517463684
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0026241193991154432
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.01313168928027153
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00654955767095089
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0063634347170591354
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004848270211368799
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.005643794313073158
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006465911399573088
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.011589878238737583
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004318178631365299
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007679691072553396
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.014860518276691437
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.029880795627832413
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004309394862502813
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.011177070438861847
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.02348809689283371
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.003918047528713942
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.011995955370366573
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0060197445563972
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.005115483421832323
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007066217716783285
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.011729811318218708
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006726349238306284
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.008325769565999508
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.010157628916203976
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004282295238226652
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004028994124382734
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006715929601341486
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.012021138332784176
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.009269850328564644
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0044059790670871735
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0038352422416210175
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.010698596946895123
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00224305409938097
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007672561798244715
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.012046674266457558
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006786379497498274
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.009103352203965187
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0038856465835124254
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.01906983181834221
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007885347120463848
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007691906299442053
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007837430573999882
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.01144812349230051
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.002447013044729829
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00341511657461524
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007496104575693607
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0022205801215022802
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.013134852051734924
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.010629749856889248
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00902454275637865
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00627803523093462
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.005597808863967657
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.016083087772130966
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.017112158238887787
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004157284274697304
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.016627365723252296
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004700012970715761
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.008654121309518814
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004021512344479561
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.011368721723556519
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.010043514892458916
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007953053340315819
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0035779629833996296
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.013969972729682922
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006033145356923342
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.022975433617830276
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007866975851356983
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007461719214916229
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.017531048506498337
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.02200850285589695
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0046983882784843445
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004640168976038694
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.005263910628855228
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00493663502857089
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.005212855525314808
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006183210760354996
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.008817891590297222
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004113639239221811
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.011118855327367783
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0020280794706195593
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00734593253582716
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.003272386034950614
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.008839339949190617
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006117332261055708
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.01356862485408783
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0011676267022266984
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.008526071906089783
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00774533161893487
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0032854750752449036
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004395252093672752
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.015136443078517914
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.013807384297251701
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.008702198974788189
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00452000554651022
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.011554716154932976
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.02135368622839451
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004753646906465292
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007770605850964785
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0044470601715147495
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.014360609464347363
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.002792482962831855
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.015156032517552376
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.010920924134552479
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0042525725439190865
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.016400722786784172
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.005385047290474176
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.012116893194615841
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.009665076620876789
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.009586702100932598
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0044525545090436935
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.002530202968046069
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006747742183506489
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0022620800882577896
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00523444265127182
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004327698610723019
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.009945528581738472
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.01534514594823122
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00324286799877882
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007684999145567417
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.02559608779847622
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.017081113532185555
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.005201948806643486
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.012547062709927559
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007718837354332209
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004031610209494829
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006734925787895918
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0015126921935006976
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006918850354850292
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004838729277253151
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.012549336068332195
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.01139003038406372
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006572640035301447
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.011791042983531952
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.01310705579817295
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006502772681415081
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007296672090888023
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.002410629764199257
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00940470676869154
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.009259294718503952
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0012499161530286074
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.011046038940548897
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.005255590192973614
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006825592368841171
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.003896621987223625
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.009972507134079933
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006412317510694265
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.005661574192345142
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.009620152413845062
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.002794489497318864
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.01208934374153614
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006451108958572149
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.008615199476480484
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.010297799482941628
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.016793478280305862
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004758499562740326
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.012090536765754223
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007091384846717119
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004148675594478846
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.003805112326517701
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.013070931658148766
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.01808342896401882
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.015535112470388412
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.014506254345178604
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004127246327698231
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004829918034374714
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0064743258990347385
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.002342748222872615
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.01829254813492298
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006455979775637388
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0027585618663579226
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.002901575993746519
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006422233767807484
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.012383484281599522
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.011794648133218288
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004571241792291403
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.008095426484942436
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.003157209139317274
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.010153896175324917
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.003384763840585947
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00768442265689373
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.009544377215206623
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004486105404794216
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.010466677136719227
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0065667880699038506
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.01912814751267433
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.008572368882596493
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0051626283675432205
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.020960286259651184
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.009611843153834343
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.01205541379749775
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.022203709930181503
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.018759403377771378
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0026516630314290524
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0045493775978684425
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007197772618383169
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004649201408028603
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00212491606362164
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.07309184223413467
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.008972772397100925
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.008098303340375423
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.015651490539312363
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.020855285227298737
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0012071572709828615
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006866902112960815
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006287941709160805
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.011426575481891632
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.047351714223623276
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0044775670394301414
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.02920595370233059
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.008252471685409546
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.011232900433242321
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0059690638445317745
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.010963519103825092
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007904534228146076
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.011462228372693062
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.017428046092391014
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.002167189959436655
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007978660054504871
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007737648673355579
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.009696866385638714
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.003916236571967602
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007330506574362516
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.001806367770768702
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.005538027733564377
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.003583934623748064
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.010186834260821342
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0182961393147707
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004013142082840204
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.008583341725170612
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.003979233559221029
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.01163121871650219
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004934888798743486
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0064965542405843735
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.003560120239853859
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006051175761967897
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0033527647610753775
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.02045019157230854
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0056164804846048355
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.005588408559560776
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.010550770908594131
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00904411356896162
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0015681104268878698
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0037848083302378654
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.010497892275452614
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004356851801276207
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.011368765495717525
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0022082512732595205
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.005215329583734274
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006253878585994244
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.015089507214725018
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.003310341387987137
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.013086208142340183
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.012412487529218197
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.012612230144441128
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00859451200813055
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.01029197033494711
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0030684226658195257
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.02027743123471737
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.009190509095788002
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00848579965531826
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.002664180938154459
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.027065303176641464
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0018501258455216885
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.01535154040902853
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0054318043403327465
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.02387446165084839
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.029452262446284294
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.010486304759979248
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.003094554878771305
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0029459521174430847
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0016198266530409455
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00522965332493186
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006692464463412762
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0037339087575674057
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.012978996150195599
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.017051976174116135
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0073138875886797905
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.011099394410848618
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.014977187849581242
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.008048170246183872
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.005771772004663944
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0050275446847081184
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.005668661091476679
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004278814885765314
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006508143153041601
# decoder_input: torch.Size([32, 62])
# ...
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.002417539246380329
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0016432240372523665
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.003851408837363124
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.005481391213834286
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0011364086531102657
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.003644328098744154
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0026897815987467766
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0012952313991263509
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.002111623762175441
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.003080179216340184
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004348890855908394
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0020633393432945013
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.003397060791030526
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.003761820262297988
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.003877046052366495
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.003591196844354272
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0007132306345738471
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0015527083305642009
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.001437424449250102
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004863306414335966
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0043741329573094845
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.001411317614838481
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0010140521917492151
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004213609267026186
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.000914131524041295
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007487510796636343
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0009675737237557769
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.002555551240220666
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0014982698485255241
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.002621027873829007
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00992527138441801
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0008947261958383024
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0007446875097230077
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0007743844762444496
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004535171668976545
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0013662711717188358
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004385906271636486
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0005861611571162939
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004272034391760826
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004639565013349056
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004354082979261875
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.002848719246685505
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0035139841493219137
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.000688662170432508
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.005355062894523144
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0005136867985129356
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.008708220906555653
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0007506167166866362
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0022825943306088448
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0008962882566265762
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0008421718957833946
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.010539406910538673
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0020354646258056164
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004458182957023382
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0022350596264004707
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.002825941191986203
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004507269710302353
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0036518005654215813
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004072078503668308
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004580765031278133
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.001143967965617776
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.003931132610887289
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00479612872004509
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004896576050668955
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.000912406190764159
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0025571200530976057
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0035927097778767347
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00493021123111248
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.001206486951559782
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0022742885630577803
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.009478299878537655
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007364137563854456
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0036002276465296745
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0017691951943561435
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006831164471805096
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004384856671094894
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0022911191917955875
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0023866731207817793
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00250359158962965
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0009157865424640477
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.005037583876401186
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0037476334255188704
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007877166382968426
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0026607608888298273
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.006315717473626137
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0012402376160025597
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0018906798213720322
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0021144745405763388
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.002613749820739031
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.002145366743206978
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0017345350934192538
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0016220941906794906
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0028967836406081915
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0023389195557683706
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.007717867381870747
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0019398846197873354
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0033503135200589895
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.005327158607542515
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0009072507382370532
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0014527237508445978
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.00564712006598711
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.017567239701747894
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.003357614390552044
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0051087746396660805
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.005515680182725191
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.002345464425161481
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0014400328509509563
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0016185969579964876
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0023954834323376417
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0037196839693933725
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.0017831353470683098
# decoder_input: torch.Size([32, 62])
# target_output: torch.Size([32, 62])
# Logits shape: torch.Size([32, 62, 119547])
# Loss: 0.004836687818169594
# Epoch 5/5, Loss: 0.0029

# %%
epoch_result
# Out:
# [[0, 2.483154097557068],
#  [1, 0.28765548260807994],
#  [2, 0.06686037291623652],
#  [3, 0.010065188904292881],
#  [4, 0.002936689836578444]]

# %% [markdown]
# # testing

# %%
# load test data
with open("/content/drive/MyDrive/transformer/test.json","r",encoding="utf-8") as f:
    data=json.load(f)
# print("Number of examples:", len(data))
# print(json.dumps(data[0], indent=2))

df = pd.DataFrame(data)
df.shape

df_exploded = df.explode("conversation")
# Reset index for convenience
df_exploded = df_exploded.reset_index(drop=True)
# Normalize the "conversation" column into separate columns
conversation_df = pd.json_normalize(df_exploded["conversation"])
# Merge the normalized data back into the exploded df
df_exploded = df_exploded.drop("conversation", axis=1).join(conversation_df)
# only need the ja_sentance and en_sentence columns
test_data=df_exploded[["ja_sentence","en_sentence"]]

# %%
# prep tensor for testing
# Tokenize the test sentences (using the same tokenizer as before)
test_data["src_ids"] = test_data["ja_sentence"].apply(lambda s: tokenizer.encode(s, add_special_tokens=True))
test_data["tgt_ids"] = test_data["en_sentence"].apply(lambda s: tokenizer.encode(s, add_special_tokens=True))

# Convert the token lists to tensors
src_id_tensors_test = [torch.tensor(ids) for ids in test_data["src_ids"]]
tgt_id_tensors_test = [torch.tensor(ids) for ids in test_data["tgt_ids"]]

# Pad the sequences
src_padded_test = pad_sequence(src_id_tensors_test, batch_first=True, padding_value=tokenizer.pad_token_id)
tgt_padded_test = pad_sequence(tgt_id_tensors_test, batch_first=True, padding_value=tokenizer.pad_token_id)

# Create a dataset and DataLoader for test data
test_dataset = TensorDataset(src_padded_test, tgt_padded_test)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)
# Out:
# <ipython-input-15-bf9676bf6f31>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data["src_ids"] = test_data["ja_sentence"].apply(lambda s: tokenizer.encode(s, add_special_tokens=True))
# <ipython-input-15-bf9676bf6f31>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data["tgt_ids"] = test_data["en_sentence"].apply(lambda s: tokenizer.encode(s, add_special_tokens=True))

# %%
src_padded_test.shape
# Out:
# torch.Size([2120, 74])

# %%
# evluation
model.eval()  # Set model to evaluation mode

total_loss = 0.0
total_correct = 0
total_tokens = 0

with torch.no_grad():
    for batch in test_dataloader:
        src_ids, tgt_ids = batch
        src_ids = src_ids.to(device)
        tgt_ids = tgt_ids.to(device)

        # Create decoder input and target output by shifting tgt_ids
        decoder_input = tgt_ids[:, :-1]  # shape: (batch_size, tgt_seq_len - 1)
        target_output = tgt_ids[:, 1:]     # shape: (batch_size, tgt_seq_len - 1)

        # Generate the target mask for the decoder
        seq_length = decoder_input.size(1)
        tgt_mask = generate_tgt_mask(seq_length, device=decoder_input.device)

        # Forward pass through the model
        logits = model(src_ids, decoder_input, tgt_mask=tgt_mask)
        # logits shape: (batch_size, tgt_seq_len - 1, vocab_size)

        # Compute loss: flatten logits and target output for CrossEntropyLoss
        loss = criterion(logits.reshape(-1, config.vocab_size), target_output.reshape(-1))
        total_loss += loss.item() #accumulating the numeric loss value from each batch

        # Compute token-level accuracy
        predictions = torch.argmax(logits, dim=-1)  # shape: (batch_size, tgt_seq_len - 1)
        # Create a mask to ignore pad tokens in the target, creates a boolean tensor label True where the target output is not the pad token,
        non_pad = target_output != tokenizer.pad_token_id
        correct = (predictions == target_output) & non_pad
        total_correct += correct.sum().item()
        total_tokens += non_pad.sum().item()

avg_loss = total_loss / len(test_dataloader)
accuracy = total_correct / total_tokens if total_tokens > 0 else 0

print("Test Loss:", avg_loss)
print("Test Accuracy:", accuracy)
# Out:
# Test Loss: 0.24047620748447726
# Test Accuracy: 0.9822249136180672

# %% [markdown]
# # option
# to save and load the model back

# %%
# Save the model's state dict to a file
# torch.save(model.state_dict(), "transformer_model.pth")

# Create a new instance of the model with the same configuration
# model_loaded = TransformerModel(config)
# model_loaded.load_state_dict(torch.load("transformer_model.pth"))
# model_loaded.to(device)  # Move the model to the appropriate device (GPU or CPU)
# model_loaded.eval()      # Set the model to evaluation mode

# %%
save_path = "/content/drive/MyDrive/transformer/transformer_model-v2.pth"

torch.save(model.state_dict(), save_path)
